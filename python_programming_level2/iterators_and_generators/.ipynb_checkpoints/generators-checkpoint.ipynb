# %%
# A simple generator function
def my_gen():
    n = 1
    print('This is printed first')
    # Generator function contains yield statements
    yield n

    n += 1
    print('This is printed second')
    yield n

    n += 1
    print('This is printed at last')
    yield n

# %%
x = my_gen()
print(x)
print(next(x))
print(next(x))
print(next(x))
print(next(x))

# %%
def newfunc():
    x = 10
    return x

print(newfunc())

# %%
#gen = my_gen()
print(my_gen())
#print(next(gen))
#print(next(gen))
#print(next(gen))

# %%
next(gen)

# %%
next(gen)

# %%
# A simple generator function
def my_gen():
    n = 1
    print('This is printed first')
    # Generator function contains yield statements
    yield n

    n += 1
    print('This is printed second')
    yield n

    n += 1
    print('This is printed at last')
    yield n


# Using for loop
for item in my_gen():
    print(item)

# %%
# Initialize the list
#my_list = [1, 3, 6, 10]

# square each term using list comprehension
#list_ = [x**2 for x in my_list]

# same thing can be done using a generator expression
# generator expressions are surrounded by parenthesis ()
generator = (x**3 for x in range(0,11))
for item in generator:
    print(item,end=" ")

#print(list_)
#print(generator)
#for item in list_:
#    print(item,end=" ")
# Out:
# 0 1 8 27 64 125 216 343 512 729 1000

# %%
print([x**3 for x in range(0,10)])
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
# Initialize the list
my_list = [1, 3, 6, 10]

a = (x**2 for x in my_list)
print(a)
print(next(a),end=" ")

print(next(a),end=" ")

print(next(a),end = " ")

print(next(a), end= " ")

#print(next(a), end= " ")

#next(a)

# %%
even = (x for x in range(2,9) if x%2==0)
print(even)
for i in even:
    print(i)
    
#print([x for x in range(5,18) if x%2==0])

# %%
even = (x for x in range(2,19) if x%2==0)
print(even)
print(next(even))
print(next(even))
print(next(even))
print(next(even))
for val in even:
    print(val)
# Out:
# <generator object <genexpr> at 0x0000022FC66C0F20>
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
comp = [x for x in range(25) if x % 3 == 0]
print(comp)

# %%
comp = {x for x in range(25) if x % 3 == 0}
print(comp)

# %%
comp = {x:x for x in range(25) if x % 3 == 0}
print(comp)

# %%
comp = (x for x in range(25) if x % 3 == 0)
print(comp)

# %%
comp = *(x for x in range(25) if x % 3 == 0),
print(comp)

# %%
def cubes(length):
    for n in range(length):
        yield n**3
        
# call the generator function like this
generator = cubes(11)
print(generator)
for cube in generator:
    print(cube,end=" ")
# Out:
# <generator object cubes at 0x000001A734DB0740>
# 0 1 8 27 64 125 216 343 512 729 1000

# %%
def cubes(length):
    for n in range(0,length):
        yield n**3
        
# call the generator function like this
generator = cubes(11)
print(generator)
print(next(generator))
print(next(generator))
print(next(generator))
print(next(generator))
#print(next(generator))
#print(next(generator))
#print(next(generator))
#print(next(generator))
#print(next(generator))
#print(next(generator))
#print(next(generator))
print("There is a break")
for val in generator:
    print(val,end="  ")
#print(next(generator))
# Out:
# <generator object cubes at 0x0000022FC66C0F90>
# 0
# 1
# 8
# 27
# There is a break
# 64  125  216  343  512  729  1000
