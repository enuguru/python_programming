# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

#print(name)
p1 = Person("Vishnu", 36)
p1.myfunc()
print(p1.name,p1.age)

# %%
class Shape:
    # constructor
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth
          
    # public member function
    def displaySides(self):
  
        # accessing protected data members
        print("Length: ", self.length)
        print("Breadth: ", self.breadth)
        
# derived class
class Rectangle(Shape):
    
    # constructor
    def __init__(self, local_length, local_breadth):
        print(self)
        # Calling the constructor of super class
        Shape.__init__(self, local_length, local_breadth)
          
    # public member function
    def calculateArea(self):
                      
        # accessing protected data members of super class
        print("Area: ", self.length * self.breadth)

        
obj= Shape(20,10)
print(obj.length)
print(obj.breadth)
obj.displaySides()
#obj.calculateArea()

#obja = Rectangle(80, 50)
#print(obja)
#print(obja.length)
#print(obja.breadth)
#obja.calculateArea() 
#obja.displaySides()
# Out:
# 20
# 10
# Length:  20
# Breadth:  10

# %%
# program to illustrate protected variables
# data members in a class

# super class
class Shape:
      
    # constructor
    def __init__(self, length, breadth):
        self._length = length
        self._breadth = breadth
          
    # public member function
    def displaySides(self):
        # accessing protected data members
        print("Length: ", self._length)
        print("Breadth: ", self._breadth)
                  
    # protected member function
    def _displaySides(self):
        # accessing protected data members
        print("Length: ", self._length)
        print("Breadth: ", self._breadth)
        
  
# derived class
class Rectangle(Shape):
  
    # constructor
    def __init__(self, local_length, local_breadth):
        # Calling the constructor of
        # Super class
        Shape.__init__(self, local_length, local_breadth)
          
    # public member function
    def calculateArea(self):                
        # accessing protected data members of super class
        print("Area: ", self._length * self._breadth)
        self._displaySides()
        self.displaySides()

  
        
#obj= Shape(20,10)
#print(obj.length)
#print(obj.breadth)
#obj.displaySides()
#obj._displaySides()
#obj.__displaySides()
#obj.calculateArea()

obja = Rectangle(80, 50)
print(obja._length)
print(obja._breadth)
obja.calculateArea() 
obja.displaySides()
obja._displaySides()
# Out:
# 80
# 50
# Area:  4000
# Length:  80
# Breadth:  50
# Length:  80
# Breadth:  50
# Length:  80
# Breadth:  50
# Length:  80
# Breadth:  50

# %%
# program to illustrate private variables
# data members in a class

# super class
class Shape:
      
    # constructor
    def __init__(self, length, breadth):
        self.__length = length
        self.__breadth = breadth
          
    # public member function
    def displaySides(self):
        # accessing protected data members
        print("Length: ", self.__length)
        print("Breadth: ", self.__breadth)
        
    # private member function
    def __displaySides(self):
        # accessing protected data members
        print("Length: ", self.__length)
        print("Breadth: ", self.__breadth)
        
  
# derived class
class Rectangle(Shape):
  
    # constructor
    def __init__(self, length, breadth):
        # Calling the constructor of
        # Super class
        Shape.__init__(self, length, breadth)
          
    # public member function
    def calculateArea(self):                
        #accessing protected data members of super class
        print("Area: ", self.__length * self.__breadth)

#obj= Shape(20,10)
#print(obj.__length)
#print(obj.__breadth)
#obj.displaySides()
#obj.__displaySides()
#obj.calculateArea()

obja = Rectangle(80, 50)
#print(obja.__length)
#print(obja.__breadth)
obja.calculateArea() 
#obja.__displaySides()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 49
#      46 obja = Rectangle(80, 50)
#      47 #print(obja.__length)
#      48 #print(obja.__breadth)
# ---> 49 obja.calculateArea()
#
# Cell In[47], line 37, in Rectangle.calculateArea(self)
#      35 def calculateArea(self):
#      36     #accessing protected data members of super class
# ---> 37     print("Area: ", self.__length * self.__breadth)
#
# AttributeError: 'Rectangle' object has no attribute '_Rectangle__length'
