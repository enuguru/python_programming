# %%
# program to show public access modifier in a class

# super class
class Student:
    
     # constructor
     def __init__(self, name, roll, branch): 
          self.name = name
          self.roll = roll
          self.branch = branch
          self.section = 2
    
     # public member function  
     def displayRollAndBranch(self):
          # accessing protected data members
          print("Roll: ", self.roll)
          print("Branch: ", self.branch)


# derived class
class Geek(Student):
 
       # constructor
       def __init__(self, name, roll, branch):
                Student.__init__(self, name, roll, branch)
         
       # public member function
       def displayDetails(self):
                   
                 # accessing protected data members of super class
                print("Name: ", self.name)
                   
                 # accessing protected member functions of super class
                self.displayRollAndBranch()
                print("section: ", self.section)


# this is the main program part
# creating objects of the derived class       
obj = Geek("R2J", 1706256, "Information Technology")
print("Name: ", obj.name)
# calling public member functions of the class
obj.displayDetails()
obj.displayRollAndBranch()
# Out:
# Name:  R2J
# Name:  R2J
# Roll:  1706256
# Branch:  Information Technology
# section:  2
# Roll:  1706256
# Branch:  Information Technology

# %%
# program to illustrate protected access modifier in a class

# super class
class Student:
    
     # constructor
     def __init__(self, name, roll, branch): 
          self._name = name
          self._roll = roll
          self._branch = branch
          self._section = 2
    
     # protected member function
     def _displayRollAndBranch(self):
          # accessing protected data members
          print("Roll: ", self._roll)
          print("Branch: ", self._branch)
            
     # public member function  
     def displayRollAndBranch(self):
          # accessing protected data members
          print("Roll: ", self._roll)
          print("Branch: ", self._branch)


# derived class
class Geek(Student):
 
       # constructor
       def __init__(self, name, roll, branch):
                Student.__init__(self, name, roll, branch)
         
       # public member function
       def displayDetails(self):
                   
                 # accessing protected data members of super class
                print("Name: ", self._name)
                   
                 # accessing protected member functions of super class
                self._displayRollAndBranch()
                print("section: ", self._section)


# this is the main program part
# creating objects of the derived class       
obj = Geek("R2J", 1706256, "Information Technology")
print("Name: ", obj._name)
# calling public member functions of the class
obj.displayDetails()
obj._displayRollAndBranch()
# Out:
# Name:  R2J
# Name:  R2J
# Roll:  1706256
# Branch:  Information Technology
# section:  2
# Roll:  1706256
# Branch:  Information Technology

# %%
# program to illustrate private access modifier in a class

# super class
class Student:
    
     # constructor
     def __init__(self, name, roll, branch): 
          self.__name = name
          self.__roll = roll
          self.__branch = branch
          self.__section = 2
    
     # public member function  
     def __displayRollAndBranch(self):
          # accessing protected data members
          print("Roll: ", self.__roll)
          print("Branch: ", self.__branch)
            
         # public member function  
     def _displayRollAndBranch(self):
          # accessing protected data members
          print("Roll: ", self.__roll)
          print("Branch: ", self.__branch)


# derived class
class Geek(Student):
 
       # constructor
       def __init__(self, name, roll, branch):
                Student.__init__(self, name, roll, branch)
         
       # public member function
       def displayDetails(self):
                   
                # accessing protected data members of super class
                print("Name: ", self.__name)
                   
                 # accessing protected member functions of super class
                self._displayRollAndBranch()
                #print("section: ", self._section)


# this is the main program part
# creating objects of the derived class       
obj = Geek("R2J", 1706256, "Information Technology")
#print("Name: ", obj.__name)
# calling public member functions of the class
obj.displayDetails()
#obj.__displayRollAndBranch()
#obj._Student__displayRollAndBranch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10304\3448336252.py in <module>
#      47 #print("Name: ", obj.__name)
#      48 # calling public member functions of the class
# ---> 49 obj.displayDetails()
#      50 #obj.__displayRollAndBranch()
#      51 #obj._Student__displayRollAndBranch()
#
# ~\AppData\Local\Temp\ipykernel_10304\3448336252.py in displayDetails(self)
#      35
#      36                 # accessing protected data members of super class
# ---> 37                 print("Name: ", self.__name)
#      38
#      39                  # accessing protected member functions of super class
#
# AttributeError: 'Geek' object has no attribute '_Geek__name'
