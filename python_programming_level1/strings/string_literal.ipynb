# %% [raw]
# Single & Double Quotes
# Enclose strings. Either single or double quotes are fine.
# Use single quotes as enclosing quotes to eliminate the need of escaping double quotes in a string, and vice versa.
# Triple Quotes
# Enclose strings containing both single and double quotes such that no escaping is needed.
# Enclose multi-line strings

# %%
newstr = "newone"
print(newstr)
print(newstr[2:5])
print(newstr[::-1])
# Out:
# newone
# won
# enowen

# %%
newstr[3] = 'f'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/3858988596.py in <module>
# ----> 1 newstr[3] = 'f'
#
# TypeError: 'str' object does not support item assignment

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World" == 'Hello World')
# Out:
# True

# %%
print('Hello\nWorld\n!')
# Out:
# Hello
# World
# !

# %%
print("Hello\nWorld\n!")
# Out:
# Hello
# World
# !

# %%
print("Hello World')
# Out:
#   File "C:\Users\Gururaj\AppData\Local\Temp/ipykernel_9864/3529077548.py", line 1
#     print("Hello World')
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
print('She said, "Thank you!"')
# Out:
# She said, "Thank you!"

# %%
print("She said, 'Thank you!'")
# Out:
# She said, 'Thank you!'

# %%
print("She said, 'Thank you! It's mine.'")
# Out:
# She said, 'Thank you! It's mine.'

# %%
print('She said, "Thank you! It's mine."')
# Out:
#   File "C:\Users\Gururaj\AppData\Local\Temp/ipykernel_9864/507817546.py", line 1
#     print('She said, "Thank you! It's mine."')
#                                     ^
# SyntaxError: invalid syntax

# %%
print('She said, "Thank you! It\'s mine."')
# Out:
# She said, "Thank you! It's mine."

# %%
print("""Hello
... World
... !""")
# Out:
# Hello
# World
# !

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
print('''She said, "Thank you! It's mine."''')
# Out:
# She said, "Thank you! It's mine."

# %%
print("""She said, "Thank you! It's mine."""")
# Out:
#   File "C:\Users\Gururaj\AppData\Local\Temp/ipykernel_9864/2832362829.py", line 1
#     print("""She said, "Thank you! It's mine."""")
#                                                   ^
# SyntaxError: EOL while scanning string literal
